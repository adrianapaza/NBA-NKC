# %%
import networkx as nx
import graph_tool.all as gt
import pandas as pd

# %%
df = pd.read_csv('N-10_K=8_I=1.csv')
df = df.set_index('Unnamed: 0')#reset index
mat = df.to_numpy()
#mat = np.genfromtxt("N-10_K=3_I=4.csv", dtype= None)
g = nx.from_numpy_matrix(mat)
g = nx.DiGraph(g)
nx.write_gml(g,"test.gml")
g2 = gt.load_graph("test.gml")
pos = gt.sfdp_layout(g2)
state = gt.minimize_blockmodel_dl(g2,B_min=2)
state.draw(pos=pos)
# Out:
# <VertexPropertyMap object with value type 'vector<double>', for Graph 0x165b90590, at 0x165b9b750>

# %%
# Out:
# <VertexPropertyMap object with value type 'vector<double>', for Graph 0x1634c8190, at 0x163442410>

# %%
print(groups)
# Out:
#   (0, 0)	504.0
#   (0, 1)	151.0
#   (0, 2)	164.0
#   (1, 0)	151.0
#   (1, 1)	98.0
#   (1, 2)	1.0
#   (2, 0)	164.0
#   (2, 1)	1.0
#   (2, 2)	134.0

# %%
pos = gt.sfdp_layout(g,groups)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-dfad58db04ee> in <module>
# ----> 1 pos = gt.sfdp_layout(g,groups=groups)
#
# /usr/local/lib/python3.7/site-packages/graph_tool/draw/__init__.py in sfdp_layout(g, vweight, eweight, pin, groups, C, K, p, theta, max_level, gamma, mu, mu_p, init_step, cooling_step, adaptive_cooling, epsilon, max_iter, pos, multilevel, coarse_method, mivs_thres, ec_thres, coarse_stack, weighted_coarse, verbose)
#     684
#     685     if pos is None:
# --> 686         pos = random_layout(g, dim=2)
#     687     _check_prop_vector(pos, name="pos", floating=True)
#     688
#
# /usr/local/lib/python3.7/site-packages/graph_tool/draw/__init__.py in random_layout(g, shape, pos, dim)
#     134
#     135     if pos is None:
# --> 136         pos = g.new_vertex_property("vector<double>")
#     137     _check_prop_vector(pos, name="pos")
# ...
